# %%
# !nvidia-smi
# Out:
# Fri Apr 19 10:35:01 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **18.01.2023** with version **YOLOv8.0.9**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://v8docs.ultralytics.com/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100% 6.23M/6.23M [00:00<00:00, 81.7MB/s]
#
# 2024-04-19 10:58:33.380500: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-19 10:58:33.380587: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-19 10:58:33.382686: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-19 10:58:34.460836: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to dog.jpeg...
# 100% 104k/104k [00:00<00:00, 86.3MB/s]
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 88.9ms
# Speed: 0.7ms pre-process, 88.9ms inference, 790.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# WARNING ⚠️ NMS time limit 0.550s exceeded

# %%
results[0].boxes.xyxy
# Out:
# tensor([[   0.,  314.,  625., 1278.],
#         [  55.,  250.,  648., 1266.],
#         [ 633.,  720.,  701.,  786.]], device='cuda:0')

# %%
results[0].boxes.conf
# Out:
# tensor([0.72713, 0.29066, 0.28455], device='cuda:0')

# %%
results[0].boxes.cls
# Out:
# tensor([ 0., 16.,  2.], device='cuda:0')

# %% [markdown]
# ## Custom Training

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/banao task
# Out:
# /content/drive/MyDrive/banao task

# %%
# %cd /content/drive/MyDrive/banao task

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=224 plots=True save=True

# %%
# !ls runs/detect/train/
# Out:
# args.yaml  weights

# %%
Image(filename='runs/detect/train3/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train3/results.png', width=600)

# %%
Image(filename='runs/detect/train3/val_batch0_pred.jpg', width=600)

# %% [markdown]
# ## Validate Custom Model

# %%
# !yolo task=detect mode=val model=runs/detect/train3/weights/best.pt data=data.yaml
# Out:
# 2024-04-19 11:49:34.515043: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-19 11:49:34.515088: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-19 11:49:34.516327: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-19 11:49:35.714494: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11129841 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/drive/MyDrive/banao task/valid/labels.cache... 47 images, 0 backgrounds, 0 corrupt: 100% 47/47 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 4, len(boxes) = 301. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0% 0/3 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:04<00:00,  1.45s/it]
#                    all         47        301      0.653      0.218       0.27      0.153
#                 button         47        127      0.692      0.496      0.537      0.279
#                dropbox         47          4          1          0          0          0
#                  image         47         18      0.302      0.222      0.144      0.105
#            input field         47         40      0.687      0.225      0.364      0.185
#                   link         47         11          1          0      0.047      0.017
#                   logo         47         33      0.741      0.242      0.447      0.178
#                  modal         47          3      0.321      0.333      0.336      0.336
#         navigation bar         47         20      0.743        0.2      0.276      0.121
#                   text         47         45      0.387      0.244       0.28      0.156
# Speed: 0.5ms pre-process, 33.3ms inference, 0.0ms loss, 39.0ms post-process per image

# %% [markdown]
# ## Inference with Custom Model

# %%
# !yolo task=detect mode=predict model=runs/detect/train3/weights/best.pt conf=0.25 source=test/images save=True
# Out:
# 2024-04-19 11:51:17.078931: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-19 11:51:17.078998: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-19 11:51:17.080577: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-19 11:51:18.227572: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11129841 parameters, 0 gradients, 28.5 GFLOPs
# image 1/23 /content/drive/MyDrive/banao task/test/images/00030_png_jpg.rf.6fc565964b95c4614e1b1622918a9f9d.jpg: 224x224 2 buttons, 1 logo, 3 texts, 8.1ms
# image 2/23 /content/drive/MyDrive/banao task/test/images/00035_png_jpg.rf.e89310d251b1fdccf1d3dcc177239b26.jpg: 224x224 2 buttons, 2 logos, 2 navigation bars, 9 texts, 7.5ms
# image 3/23 /content/drive/MyDrive/banao task/test/images/00062_png_jpg.rf.2bcf7cf0885a5bc46b63d17fb2273cb2.jpg: 224x224 3 buttons, 2 images, 7.7ms
# image 4/23 /content/drive/MyDrive/banao task/test/images/00085_png_jpg.rf.77d806ba4e56241d88d9a41a5274233b.jpg: 224x224 1 button, 2 images, 1 logo, 1 navigation bar, 2 texts, 7.7ms
# image 5/23 /content/drive/MyDrive/banao task/test/images/00095_png_jpg.rf.5465364cd88281b19b0c2f3ddd3f04df.jpg: 224x224 1 logo, 7.8ms
# image 6/23 /content/drive/MyDrive/banao task/test/images/00130_png_jpg.rf.30cd39abebe30ce0892e636a4b815ad9.jpg: 224x224 2 buttons, 2 texts, 10.3ms
# image 7/23 /content/drive/MyDrive/banao task/test/images/00132_png_jpg.rf.7ca54237a520a02a664c20cd5355bf68.jpg: 224x224 2 buttons, 2 texts, 8.0ms
# image 8/23 /content/drive/MyDrive/banao task/test/images/00138_png_jpg.rf.f086ab2d3b26870256eb4155b9e378de.jpg: 224x224 2 buttons, 1 logo, 1 modal, 1 text, 8.0ms
# image 9/23 /content/drive/MyDrive/banao task/test/images/00148_png_jpg.rf.c1823cebf0e22ff5cf26d40ea62438c2.jpg: 224x224 3 buttons, 1 image, 1 logo, 1 text, 10.3ms
# image 10/23 /content/drive/MyDrive/banao task/test/images/00167_png_jpg.rf.a73fcad963fd429056892cdb1dd85f8c.jpg: 224x224 1 button, 1 image, 1 input field, 7 texts, 11.1ms
# image 11/23 /content/drive/MyDrive/banao task/test/images/00199_png_jpg.rf.0cb61c77ff962fd882944f52ae5e46b8.jpg: 224x224 1 button, 1 image, 1 input field, 7.7ms
# image 12/23 /content/drive/MyDrive/banao task/test/images/00208_png_jpg.rf.7f7883b007a2b54de77cdcbbdf63ecbb.jpg: 224x224 4 buttons, 1 image, 1 input field, 2 logos, 2 texts, 10.2ms
# image 13/23 /content/drive/MyDrive/banao task/test/images/00329_png_jpg.rf.d99fb05768d22e15c57fe76447dbd46b.jpg: 224x224 7.9ms
# image 14/23 /content/drive/MyDrive/banao task/test/images/00384_png_jpg.rf.f33d082d096630bd12332e596d509956.jpg: 224x224 2 input fields, 1 text, 12.0ms
# image 15/23 /content/drive/MyDrive/banao task/test/images/00437_png_jpg.rf.1aa19f1d1048ddb901ff755f697b17e8.jpg: 224x224 1 button, 1 modal, 1 text, 7.6ms
# image 16/23 /content/drive/MyDrive/banao task/test/images/00454_png_jpg.rf.eac3b826327cc07ee62ebbc9757e0315.jpg: 224x224 3 buttons, 1 text, 7.5ms
# image 17/23 /content/drive/MyDrive/banao task/test/images/00495_png_jpg.rf.47e987e0cf765671de59dc86b830240d.jpg: 224x224 1 image, 1 navigation bar, 7.7ms
# image 18/23 /content/drive/MyDrive/banao task/test/images/00498_png_jpg.rf.75381305abc8fcb1fa5cf426fe444103.jpg: 224x224 2 buttons, 1 logo, 5 texts, 7.6ms
# image 19/23 /content/drive/MyDrive/banao task/test/images/00527_png_jpg.rf.aba29e7e6c8f626378ae7e41c7c422ec.jpg: 224x224 3 buttons, 2 texts, 7.7ms
# image 20/23 /content/drive/MyDrive/banao task/test/images/00566_png_jpg.rf.62bf34e175fc709a7d8f4dd04461ee48.jpg: 224x224 2 buttons, 1 text, 9.1ms
# image 21/23 /content/drive/MyDrive/banao task/test/images/00647_png_jpg.rf.bc70b638121d0dd6b54c50125afb0ddf.jpg: 224x224 1 button, 3 input fields, 1 navigation bar, 1 text, 8.0ms
# image 22/23 /content/drive/MyDrive/banao task/test/images/00690_png_jpg.rf.9cf7a5cfaaebaa62f0b305261122161d.jpg: 224x224 2 buttons, 2 images, 3 texts, 7.6ms
# image 23/23 /content/drive/MyDrive/banao task/test/images/Screenshot-2023-12-13-135328_png.rf.27ab518565618b6f45e6b8134b6d1ebd.jpg: 224x224 1 input field, 8.8ms
# Speed: 0.4ms pre-process, 8.5ms inference, 24.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
